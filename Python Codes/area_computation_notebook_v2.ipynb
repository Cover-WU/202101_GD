# %%
# _*_ coding: utf-8 _*_
# @author: Cover WU
# date: 2021-02-19
# in reference of Dr. Liao's code work.

import numpy as np
import pandas as pd
import os
import cv2 as cv
from math import sqrt

from google.colab import drive
drive.mount('/content/Google_Drive')

# !unzip /content/Google_Drive/MyDrive/seg_results_3.zip

print("Runtime completed.")

# %%
def create_key_pair():
    pixel_color = np.array([
        [128,  64, 128],
        [244,  35, 232],
        [ 70,  70,  70],
        [102, 102, 156],
        [190, 153, 153],
        [153, 153, 153],
        [250, 170,  30],
        [220, 220,   0],
        [107, 142,  35],
        [152, 251, 152],
        [ 70, 130, 180],
        [220,  20,  60],
        [255,   0,   0],
        [  0,   0, 142],
        [  0,   0,  70],
        [  0,  60, 100],
        [  0,  80, 100],
        [  0,   0, 230],
        [119,  11,  32],
        [  0,   0,   0]
    ], dtype='uint8')
    pixel_color = pd.DataFrame(pixel_color, columns=['channel1', 'channel2', 'channel3'])
    color_label = np.array(['road', 'sidewalk', 'building', 'wall', 'fence', 'pole', 'traffic light',
                              'traffic sign', 'vegetation', 'terrain', 'sky', 'person', 'rider', 'car',
                              'truck', 'bus', 'train', 'motorcycle', 'bicycle', 'unlabelled'])
    color_label = pd.Series(color_label)
    pixel_color['label'] = color_label
    return pixel_color

def one_frame_ratio(frame):
    '''
        function: get in a color map frame and return a one-row df with pixel number.
        argument: frame is a image class object.
    '''
    # number of all kinds of pixel in one frame.

    frame_resized = cv.resize(frame, (WIDTH, HEIGHT))
    pixels = frame_resized.reshape((WIDTH * HEIGHT, 3))
    df_pixels = pd.DataFrame(pixels, columns=['channel1', 'channel2', 'channel3'])
    df_semantic_pair = create_key_pair()
    df_labelled = pd.merge(df_pixels, df_semantic_pair, how='left', on=['channel1', 'channel2', 'channel3'])
    df_labelled['count'] = 1
    df_labelled_count = df_labelled.loc[:, ['label', 'count']]
    df_labelled_ratio = df_labelled_count.groupby('label').sum() / (1.0 * WIDTH * HEIGHT)
    return df_labelled_ratio.T


def get_video_ratio(video_name):
    '''
        function: get in name of the video and return the video semantic ratio.
        argument: video_name: name of the video, string.
    '''
    frame_results = pd.DataFrame(columns = ['road', 'sidewalk', 'building', 'wall', 'fence', 'pole', 'traffic light',
                                      'traffic sign', 'vegetation', 'terrain', 'sky', 'person', 'rider', 'car',
                                      'truck', 'bus', 'train', 'motorcycle', 'bicycle', 'unlabelled'])

    videopath = segpath + '/' + video_name
    colormap_list = os.listdir(videopath)
    colormap_list.sort()
    for colormap_name in colormap_list:
        colormap_path = videopath + '/' + colormap_name
        img = cv.imread(colormap_path)
        ratio = one_frame_ratio(img)
        frame_results = frame_results.append(ratio).fillna(0)
        print(video_name + ', ' + colormap_name + " computation complete.")
    result = frame_results.mean()
    result = pd.DataFrame(result, columns=[video_name])
    return result.T

if __name__ == '__main__':
    WIDTH, HEIGHT = 720, 480

    segpath = r'/content/content/cityscapes_seg_results'
    media_list = os.listdir(segpath)
    final_data = pd.DataFrame(columns = ['road', 'sidewalk', 'building', 'wall', 'fence', 'pole', 'traffic light',
                                           'traffic sign', 'vegetation', 'terrain', 'sky', 'person', 'rider', 'car',
                                           'truck', 'bus', 'train', 'motorcycle', 'bicycle', 'unlabelled', 'video'])
    for media in media_list:
        ratio_from_one_video = get_video_ratio(media)
        final_data = final_data.append(ratio_from_one_video)
    final_data.to_csv('area_computation_results')
# Out:
# Streaming output truncated to the last 5000 lines.
# Metro_H, frame004003.png computation complete.
# Metro_H, frame004004.png computation complete.
# Metro_H, frame004005.png computation complete.
# Metro_H, frame004006.png computation complete.
# Metro_H, frame004007.png computation complete.
# Metro_H, frame004008.png computation complete.
# Metro_H, frame004009.png computation complete.
# Metro_H, frame004010.png computation complete.
# Metro_H, frame004011.png computation complete.
# Metro_H, frame004012.png computation complete.
# Metro_H, frame004013.png computation complete.
# Metro_H, frame004014.png computation complete.
# Metro_H, frame004015.png computation complete.
# Metro_H, frame004016.png computation complete.
# Metro_H, frame004017.png computation complete.
# Metro_H, frame004018.png computation complete.
# Metro_H, frame004019.png computation complete.
# Metro_H, frame004020.png computation complete.
# Metro_H, frame004021.png computation complete.
# Metro_H, frame004022.png computation complete.
# Metro_H, frame004023.png computation complete.
# Metro_H, frame004024.png computation complete.
# Metro_H, frame004025.png computation complete.
# Metro_H, frame004026.png computation complete.
# Metro_H, frame004027.png computation complete.
# Metro_H, frame004028.png computation complete.
# Metro_H, frame004029.png computation complete.
# Metro_H, frame004030.png computation complete.
# Metro_H, frame004031.png computation complete.
# Metro_H, frame004032.png computation complete.
# Metro_H, frame004033.png computation complete.
# Metro_H, frame004034.png computation complete.
# Metro_H, frame004035.png computation complete.
# Metro_H, frame004036.png computation complete.
# Metro_H, frame004037.png computation complete.
# Metro_H, frame004038.png computation complete.
# Metro_H, frame004039.png computation complete.
# Metro_H, frame004040.png computation complete.
# Metro_H, frame004041.png computation complete.
# Metro_H, frame004042.png computation complete.
# Metro_H, frame004043.png computation complete.
# Metro_H, frame004044.png computation complete.
# Metro_H, frame004045.png computation complete.
# Metro_H, frame004046.png computation complete.
# Metro_H, frame004047.png computation complete.
# Metro_H, frame004048.png computation complete.
# Metro_H, frame004049.png computation complete.
# Metro_H, frame004050.png computation complete.
# Metro_H, frame004051.png computation complete.
# Metro_H, frame004052.png computation complete.
# Metro_H, frame004053.png computation complete.
# Metro_H, frame004054.png computation complete.
# Metro_H, frame004055.png computation complete.
# Metro_H, frame004056.png computation complete.
# Metro_H, frame004057.png computation complete.
# Metro_H, frame004058.png computation complete.
# Metro_H, frame004059.png computation complete.
# Metro_H, frame004060.png computation complete.
# Metro_H, frame004061.png computation complete.
# Metro_H, frame004062.png computation complete.
# Metro_H, frame004063.png computation complete.
# Metro_H, frame004064.png computation complete.
# Metro_H, frame004065.png computation complete.
# Metro_H, frame004066.png computation complete.
# Metro_H, frame004067.png computation complete.
# Metro_H, frame004068.png computation complete.
# Metro_H, frame004069.png computation complete.
# Metro_H, frame004070.png computation complete.
# Metro_H, frame004071.png computation complete.
# Metro_H, frame004072.png computation complete.
# Metro_H, frame004073.png computation complete.
# Metro_H, frame004074.png computation complete.
# Metro_H, frame004075.png computation complete.
# Metro_H, frame004076.png computation complete.
# Metro_H, frame004077.png computation complete.
# Metro_H, frame004078.png computation complete.
# Metro_H, frame004079.png computation complete.
# Metro_H, frame004080.png computation complete.
# Metro_H, frame004081.png computation complete.
# Metro_H, frame004082.png computation complete.
# Metro_H, frame004083.png computation complete.
# Metro_H, frame004084.png computation complete.
# Metro_H, frame004085.png computation complete.
# Metro_H, frame004086.png computation complete.
# Metro_H, frame004087.png computation complete.
# Metro_H, frame004088.png computation complete.
# Metro_H, frame004089.png computation complete.
# Metro_H, frame004090.png computation complete.
# Metro_H, frame004091.png computation complete.
# Metro_H, frame004092.png computation complete.
# Metro_H, frame004093.png computation complete.
# Metro_H, frame004094.png computation complete.
# Metro_H, frame004095.png computation complete.
# Metro_H, frame004096.png computation complete.
# Metro_H, frame004097.png computation complete.
# Metro_H, frame004098.png computation complete.
# Metro_H, frame004099.png computation complete.
# Metro_H, frame004100.png computation complete.
# Metro_H, frame004101.png computation complete.
# Metro_H, frame004102.png computation complete.
# Metro_H, frame004103.png computation complete.
# Metro_H, frame004104.png computation complete.
# Metro_H, frame004105.png computation complete.
# Metro_H, frame004106.png computation complete.
# Metro_H, frame004107.png computation complete.
# Metro_H, frame004108.png computation complete.
# Metro_H, frame004109.png computation complete.
# Metro_H, frame004110.png computation complete.
# Metro_H, frame004111.png computation complete.
# Metro_H, frame004112.png computation complete.
# Metro_H, frame004113.png computation complete.
# Metro_H, frame004114.png computation complete.
# Metro_H, frame004115.png computation complete.
# Metro_H, frame004116.png computation complete.
# Metro_H, frame004117.png computation complete.
# Metro_H, frame004118.png computation complete.
# Metro_H, frame004119.png computation complete.
# Metro_H, frame004120.png computation complete.
# Metro_H, frame004121.png computation complete.
# Metro_H, frame004122.png computation complete.
# Metro_H, frame004123.png computation complete.
# Metro_H, frame004124.png computation complete.
# Metro_H, frame004125.png computation complete.
# Metro_H, frame004126.png computation complete.
# Metro_H, frame004127.png computation complete.
# Metro_H, frame004128.png computation complete.
# Metro_H, frame004129.png computation complete.
# Metro_H, frame004130.png computation complete.
# Metro_H, frame004131.png computation complete.
# Metro_H, frame004132.png computation complete.
# Metro_H, frame004133.png computation complete.
# Metro_H, frame004134.png computation complete.
# Metro_H, frame004135.png computation complete.
# Metro_H, frame004136.png computation complete.
# Metro_H, frame004137.png computation complete.
# Metro_H, frame004138.png computation complete.
# Metro_H, frame004139.png computation complete.
# Metro_H, frame004140.png computation complete.
# Metro_H, frame004141.png computation complete.
# Metro_H, frame004142.png computation complete.
# Metro_H, frame004143.png computation complete.
# Metro_H, frame004144.png computation complete.
# Metro_H, frame004145.png computation complete.
# Metro_H, frame004146.png computation complete.
# Metro_H, frame004147.png computation complete.
# Metro_H, frame004148.png computation complete.
# Metro_H, frame004149.png computation complete.
# Metro_H, frame004150.png computation complete.
# Metro_H, frame004151.png computation complete.
# Metro_H, frame004152.png computation complete.
# Metro_H, frame004153.png computation complete.
# Metro_H, frame004154.png computation complete.
# Metro_H, frame004155.png computation complete.
# Metro_H, frame004156.png computation complete.
# Metro_H, frame004157.png computation complete.
# Metro_H, frame004158.png computation complete.
# Metro_H, frame004159.png computation complete.
# Metro_H, frame004160.png computation complete.
# Metro_H, frame004161.png computation complete.
# Metro_H, frame004162.png computation complete.
# Metro_H, frame004163.png computation complete.
# Metro_H, frame004164.png computation complete.
# Metro_H, frame004165.png computation complete.
# Metro_H, frame004166.png computation complete.
# Metro_H, frame004167.png computation complete.
# Metro_H, frame004168.png computation complete.
# Metro_H, frame004169.png computation complete.
# Metro_H, frame004170.png computation complete.
# Metro_H, frame004171.png computation complete.
# Metro_H, frame004172.png computation complete.
# Metro_H, frame004173.png computation complete.
# Metro_H, frame004174.png computation complete.
# Metro_H, frame004175.png computation complete.
# Metro_H, frame004176.png computation complete.
# Metro_H, frame004177.png computation complete.
# Metro_H, frame004178.png computation complete.
# Metro_H, frame004179.png computation complete.
# Metro_H, frame004180.png computation complete.
# Metro_H, frame004181.png computation complete.
# Metro_H, frame004182.png computation complete.
# Metro_H, frame004183.png computation complete.
# Metro_H, frame004184.png computation complete.
# Metro_H, frame004185.png computation complete.
# Metro_H, frame004186.png computation complete.
# Metro_H, frame004187.png computation complete.
# Metro_H, frame004188.png computation complete.
# Metro_H, frame004189.png computation complete.
# Metro_H, frame004190.png computation complete.
# Metro_H, frame004191.png computation complete.
# Metro_H, frame004192.png computation complete.
# Metro_H, frame004193.png computation complete.
# Metro_H, frame004194.png computation complete.
# Metro_H, frame004195.png computation complete.
# Metro_H, frame004196.png computation complete.
# Metro_H, frame004197.png computation complete.
# Metro_H, frame004198.png computation complete.
# Metro_H, frame004199.png computation complete.
# Metro_H, frame004200.png computation complete.
# Metro_H, frame004201.png computation complete.
# Metro_H, frame004202.png computation complete.
# Metro_H, frame004203.png computation complete.
# Metro_H, frame004204.png computation complete.
# Metro_H, frame004205.png computation complete.
# Metro_H, frame004206.png computation complete.
# Metro_H, frame004207.png computation complete.
# Metro_H, frame004208.png computation complete.
# Metro_H, frame004209.png computation complete.
# Metro_H, frame004210.png computation complete.
# Metro_H, frame004211.png computation complete.
# Metro_H, frame004212.png computation complete.
# Metro_H, frame004213.png computation complete.
# Metro_H, frame004214.png computation complete.
# Metro_H, frame004215.png computation complete.
# Metro_H, frame004216.png computation complete.
# Metro_H, frame004217.png computation complete.
# Metro_H, frame004218.png computation complete.
# Metro_H, frame004219.png computation complete.
# Metro_H, frame004220.png computation complete.
# Metro_H, frame004221.png computation complete.
# Metro_H, frame004222.png computation complete.
# Metro_H, frame004223.png computation complete.
# Metro_H, frame004224.png computation complete.
# Metro_H, frame004225.png computation complete.
# Metro_H, frame004226.png computation complete.
# Metro_H, frame004227.png computation complete.
# Metro_H, frame004228.png computation complete.
# Metro_H, frame004229.png computation complete.
# Metro_H, frame004230.png computation complete.
# Metro_H, frame004231.png computation complete.
# Metro_H, frame004232.png computation complete.
# Metro_H, frame004233.png computation complete.
# Metro_H, frame004234.png computation complete.
# Metro_H, frame004235.png computation complete.
# Metro_H, frame004236.png computation complete.
# Metro_H, frame004237.png computation complete.
# Metro_H, frame004238.png computation complete.
# Metro_H, frame004239.png computation complete.
# Metro_H, frame004240.png computation complete.
# Metro_H, frame004241.png computation complete.
# Metro_H, frame004242.png computation complete.
# Metro_H, frame004243.png computation complete.
# Metro_H, frame004244.png computation complete.
# Metro_H, frame004245.png computation complete.
# Metro_H, frame004246.png computation complete.
# Metro_H, frame004247.png computation complete.
# Metro_H, frame004248.png computation complete.
# Metro_H, frame004249.png computation complete.
# Metro_H, frame004250.png computation complete.
# Metro_H, frame004251.png computation complete.
# Metro_H, frame004252.png computation complete.
# Metro_H, frame004253.png computation complete.
# Metro_H, frame004254.png computation complete.
# Metro_H, frame004255.png computation complete.
# Metro_H, frame004256.png computation complete.
# Metro_H, frame004257.png computation complete.
# Metro_H, frame004258.png computation complete.
# Metro_H, frame004259.png computation complete.
# Metro_H, frame004260.png computation complete.
# Metro_H, frame004261.png computation complete.
# Metro_H, frame004262.png computation complete.
# Metro_H, frame004263.png computation complete.
# Metro_H, frame004264.png computation complete.
# Metro_H, frame004265.png computation complete.
# Metro_H, frame004266.png computation complete.
# Metro_H, frame004267.png computation complete.
# Metro_H, frame004268.png computation complete.
# Metro_H, frame004269.png computation complete.
# Metro_H, frame004270.png computation complete.
# Metro_H, frame004271.png computation complete.
# Metro_H, frame004272.png computation complete.
# Metro_H, frame004273.png computation complete.
# Metro_H, frame004274.png computation complete.
# Metro_H, frame004275.png computation complete.
# Metro_H, frame004276.png computation complete.
# Metro_H, frame004277.png computation complete.
# Metro_H, frame004278.png computation complete.
# Metro_H, frame004279.png computation complete.
# Metro_H, frame004280.png computation complete.
# Metro_H, frame004281.png computation complete.
# Metro_H, frame004282.png computation complete.
# Metro_H, frame004283.png computation complete.
# Metro_H, frame004284.png computation complete.
# Metro_H, frame004285.png computation complete.
# Metro_H, frame004286.png computation complete.
# Metro_H, frame004287.png computation complete.
# Metro_H, frame004288.png computation complete.
# Metro_H, frame004289.png computation complete.
# Metro_H, frame004290.png computation complete.
# Metro_H, frame004291.png computation complete.
# Metro_H, frame004292.png computation complete.
# Metro_H, frame004293.png computation complete.
# Metro_H, frame004294.png computation complete.
# Metro_H, frame004295.png computation complete.
# Metro_H, frame004296.png computation complete.
# Metro_H, frame004297.png computation complete.
# Metro_H, frame004298.png computation complete.
# Metro_H, frame004299.png computation complete.
# Metro_H, frame004300.png computation complete.
# Metro_H, frame004301.png computation complete.
# Metro_H, frame004302.png computation complete.
# Metro_H, frame004303.png computation complete.
# Metro_H, frame004304.png computation complete.
# Metro_H, frame004305.png computation complete.
# Metro_H, frame004306.png computation complete.
# Metro_H, frame004307.png computation complete.
# Metro_H, frame004308.png computation complete.
# Metro_H, frame004309.png computation complete.
# Metro_H, frame004310.png computation complete.
# Metro_H, frame004311.png computation complete.
# Metro_H, frame004312.png computation complete.
# Metro_H, frame004313.png computation complete.
# Metro_H, frame004314.png computation complete.
# Metro_H, frame004315.png computation complete.
# Metro_H, frame004316.png computation complete.
# Metro_H, frame004317.png computation complete.
# Metro_H, frame004318.png computation complete.
# Metro_H, frame004319.png computation complete.
# Metro_H, frame004320.png computation complete.
# Metro_H, frame004321.png computation complete.
# Metro_H, frame004322.png computation complete.
# Metro_H, frame004323.png computation complete.
# Metro_H, frame004324.png computation complete.
# Metro_H, frame004325.png computation complete.
# Metro_H, frame004326.png computation complete.
# Metro_H, frame004327.png computation complete.
# Metro_H, frame004328.png computation complete.
# Metro_H, frame004329.png computation complete.
# Metro_H, frame004330.png computation complete.
# Metro_H, frame004331.png computation complete.
# Metro_H, frame004332.png computation complete.
# Metro_H, frame004333.png computation complete.
# Metro_H, frame004334.png computation complete.
# Metro_H, frame004335.png computation complete.
# Metro_H, frame004336.png computation complete.
# Metro_H, frame004337.png computation complete.
# Metro_H, frame004338.png computation complete.
# Metro_H, frame004339.png computation complete.
# Metro_H, frame004340.png computation complete.
# Metro_H, frame004341.png computation complete.
# Metro_H, frame004342.png computation complete.
# Metro_H, frame004343.png computation complete.
# Metro_H, frame004344.png computation complete.
# Metro_H, frame004345.png computation complete.
# Metro_H, frame004346.png computation complete.
# Metro_H, frame004347.png computation complete.
# Metro_H, frame004348.png computation complete.
# Metro_H, frame004349.png computation complete.
# Metro_H, frame004350.png computation complete.
# Metro_H, frame004351.png computation complete.
# Metro_H, frame004352.png computation complete.
# Metro_H, frame004353.png computation complete.
# Metro_H, frame004354.png computation complete.
# Metro_H, frame004355.png computation complete.
# Metro_H, frame004356.png computation complete.
# Metro_H, frame004357.png computation complete.
# Metro_H, frame004358.png computation complete.
# Metro_H, frame004359.png computation complete.
# Metro_H, frame004360.png computation complete.
# Metro_H, frame004361.png computation complete.
# Metro_H, frame004362.png computation complete.
# Metro_H, frame004363.png computation complete.
# Metro_H, frame004364.png computation complete.
# Metro_H, frame004365.png computation complete.
# Metro_H, frame004366.png computation complete.
# Metro_H, frame004367.png computation complete.
# Metro_H, frame004368.png computation complete.
# Metro_H, frame004369.png computation complete.
# Metro_H, frame004370.png computation complete.
# Metro_H, frame004371.png computation complete.
# Metro_H, frame004372.png computation complete.
# Metro_H, frame004373.png computation complete.
# Metro_H, frame004374.png computation complete.
# Metro_H, frame004375.png computation complete.
# Metro_H, frame004376.png computation complete.
# Metro_H, frame004377.png computation complete.
# Metro_H, frame004378.png computation complete.
# Metro_H, frame004379.png computation complete.
# Metro_H, frame004380.png computation complete.
# Metro_H, frame004381.png computation complete.
# Metro_H, frame004382.png computation complete.
# Metro_H, frame004383.png computation complete.
# Metro_H, frame004384.png computation complete.
# Metro_H, frame004385.png computation complete.
# Metro_H, frame004386.png computation complete.
# Metro_H, frame004387.png computation complete.
# Metro_H, frame004388.png computation complete.
# Metro_H, frame004389.png computation complete.
# Metro_H, frame004390.png computation complete.
# Metro_H, frame004391.png computation complete.
# Metro_H, frame004392.png computation complete.
# Metro_H, frame004393.png computation complete.
# Metro_H, frame004394.png computation complete.
# Metro_H, frame004395.png computation complete.
# Metro_H, frame004396.png computation complete.
# Metro_H, frame004397.png computation complete.
# Metro_H, frame004398.png computation complete.
# Metro_H, frame004399.png computation complete.
# Metro_H, frame004400.png computation complete.
# Metro_H, frame004401.png computation complete.
# Metro_H, frame004402.png computation complete.
# Metro_H, frame004403.png computation complete.
# Metro_H, frame004404.png computation complete.
# Metro_H, frame004405.png computation complete.
# Metro_H, frame004406.png computation complete.
# Metro_H, frame004407.png computation complete.
# Metro_H, frame004408.png computation complete.
# Metro_H, frame004409.png computation complete.
# Metro_H, frame004410.png computation complete.
# Metro_H, frame004411.png computation complete.
# Metro_H, frame004412.png computation complete.
# Metro_H, frame004413.png computation complete.
# Metro_H, frame004414.png computation complete.
# Metro_H, frame004415.png computation complete.
# Metro_H, frame004416.png computation complete.
# Metro_H, frame004417.png computation complete.
# Metro_H, frame004418.png computation complete.
# Metro_H, frame004419.png computation complete.
# Metro_H, frame004420.png computation complete.
# Metro_H, frame004421.png computation complete.
# Metro_H, frame004422.png computation complete.
# Metro_H, frame004423.png computation complete.
# Metro_H, frame004424.png computation complete.
# Metro_H, frame004425.png computation complete.
# Metro_H, frame004426.png computation complete.
# Metro_H, frame004427.png computation complete.
# Metro_H, frame004428.png computation complete.
# Metro_H, frame004429.png computation complete.
# Metro_H, frame004430.png computation complete.
# Metro_H, frame004431.png computation complete.
# Metro_H, frame004432.png computation complete.
# Metro_H, frame004433.png computation complete.
# Metro_H, frame004434.png computation complete.
# Metro_H, frame004435.png computation complete.
# Metro_H, frame004436.png computation complete.
# Metro_H, frame004437.png computation complete.
# Metro_H, frame004438.png computation complete.
# Metro_H, frame004439.png computation complete.
# Metro_H, frame004440.png computation complete.
# Metro_H, frame004441.png computation complete.
# Metro_H, frame004442.png computation complete.
# Metro_H, frame004443.png computation complete.
# Metro_H, frame004444.png computation complete.
# Metro_H, frame004445.png computation complete.
# Metro_H, frame004446.png computation complete.
# Metro_H, frame004447.png computation complete.
# Metro_H, frame004448.png computation complete.
# Metro_H, frame004449.png computation complete.
# Metro_H, frame004450.png computation complete.
# Metro_H, frame004451.png computation complete.
# Metro_H, frame004452.png computation complete.
# Metro_H, frame004453.png computation complete.
# Metro_H, frame004454.png computation complete.
# Metro_H, frame004455.png computation complete.
# Metro_H, frame004456.png computation complete.
# Metro_H, frame004457.png computation complete.
# Metro_H, frame004458.png computation complete.
# Metro_H, frame004459.png computation complete.
# Metro_H, frame004460.png computation complete.
# Metro_H, frame004461.png computation complete.
# Metro_H, frame004462.png computation complete.
# Metro_H, frame004463.png computation complete.
# Metro_H, frame004464.png computation complete.
# Metro_H, frame004465.png computation complete.
# Metro_H, frame004466.png computation complete.
# Metro_H, frame004467.png computation complete.
# Metro_H, frame004468.png computation complete.
# Metro_H, frame004469.png computation complete.
# Metro_H, frame004470.png computation complete.
# Metro_H, frame004471.png computation complete.
# Metro_H, frame004472.png computation complete.
# Metro_H, frame004473.png computation complete.
# Metro_H, frame004474.png computation complete.
# Metro_H, frame004475.png computation complete.
# Metro_H, frame004476.png computation complete.
# Metro_H, frame004477.png computation complete.
# Metro_H, frame004478.png computation complete.
# Metro_H, frame004479.png computation complete.
# Metro_H, frame004480.png computation complete.
# Metro_H, frame004481.png computation complete.
# Metro_H, frame004482.png computation complete.
# Metro_H, frame004483.png computation complete.
# Metro_H, frame004484.png computation complete.
# Metro_H, frame004485.png computation complete.
# Metro_H, frame004486.png computation complete.
# Metro_H, frame004487.png computation complete.
# Metro_H, frame004488.png computation complete.
# Metro_H, frame004489.png computation complete.
# Metro_H, frame004490.png computation complete.
# Metro_H, frame004491.png computation complete.
# Metro_H, frame004492.png computation complete.
# Metro_H, frame004493.png computation complete.
# Metro_H, frame004494.png computation complete.
# Metro_H, frame004495.png computation complete.
# Metro_H, frame004496.png computation complete.
# Metro_H, frame004497.png computation complete.
# Metro_H, frame004498.png computation complete.
# Metro_H, frame004499.png computation complete.
# Metro_H, frame004500.png computation complete.
# Metro_H, frame004501.png computation complete.
# Metro_L, frame000001.png computation complete.
# Metro_L, frame000002.png computation complete.
# Metro_L, frame000003.png computation complete.
# Metro_L, frame000004.png computation complete.
# Metro_L, frame000005.png computation complete.
# Metro_L, frame000006.png computation complete.
# Metro_L, frame000007.png computation complete.
# Metro_L, frame000008.png computation complete.
# Metro_L, frame000009.png computation complete.
# Metro_L, frame000010.png computation complete.
# Metro_L, frame000011.png computation complete.
# Metro_L, frame000012.png computation complete.
# Metro_L, frame000013.png computation complete.
# Metro_L, frame000014.png computation complete.
# Metro_L, frame000015.png computation complete.
# Metro_L, frame000016.png computation complete.
# Metro_L, frame000017.png computation complete.
# Metro_L, frame000018.png computation complete.
# Metro_L, frame000019.png computation complete.
# Metro_L, frame000020.png computation complete.
# Metro_L, frame000021.png computation complete.
# Metro_L, frame000022.png computation complete.
# Metro_L, frame000023.png computation complete.
# Metro_L, frame000024.png computation complete.
# Metro_L, frame000025.png computation complete.
# Metro_L, frame000026.png computation complete.
# Metro_L, frame000027.png computation complete.
# Metro_L, frame000028.png computation complete.
# Metro_L, frame000029.png computation complete.
# Metro_L, frame000030.png computation complete.
# Metro_L, frame000031.png computation complete.
# Metro_L, frame000032.png computation complete.
# Metro_L, frame000033.png computation complete.
# Metro_L, frame000034.png computation complete.
# Metro_L, frame000035.png computation complete.
# Metro_L, frame000036.png computation complete.
# Metro_L, frame000037.png computation complete.
# Metro_L, frame000038.png computation complete.
# Metro_L, frame000039.png computation complete.
# Metro_L, frame000040.png computation complete.
# Metro_L, frame000041.png computation complete.
# Metro_L, frame000042.png computation complete.
# Metro_L, frame000043.png computation complete.
# Metro_L, frame000044.png computation complete.
# Metro_L, frame000045.png computation complete.
# Metro_L, frame000046.png computation complete.
# Metro_L, frame000047.png computation complete.
# Metro_L, frame000048.png computation complete.
# Metro_L, frame000049.png computation complete.
# Metro_L, frame000050.png computation complete.
# Metro_L, frame000051.png computation complete.
# Metro_L, frame000052.png computation complete.
# Metro_L, frame000053.png computation complete.
# Metro_L, frame000054.png computation complete.
# Metro_L, frame000055.png computation complete.
# Metro_L, frame000056.png computation complete.
# Metro_L, frame000057.png computation complete.
# Metro_L, frame000058.png computation complete.
# Metro_L, frame000059.png computation complete.
# Metro_L, frame000060.png computation complete.
# Metro_L, frame000061.png computation complete.
# Metro_L, frame000062.png computation complete.
# Metro_L, frame000063.png computation complete.
# Metro_L, frame000064.png computation complete.
# Metro_L, frame000065.png computation complete.
# Metro_L, frame000066.png computation complete.
# Metro_L, frame000067.png computation complete.
# Metro_L, frame000068.png computation complete.
# Metro_L, frame000069.png computation complete.
# Metro_L, frame000070.png computation complete.
# Metro_L, frame000071.png computation complete.
# Metro_L, frame000072.png computation complete.
# Metro_L, frame000073.png computation complete.
# Metro_L, frame000074.png computation complete.
# Metro_L, frame000075.png computation complete.
# Metro_L, frame000076.png computation complete.
# Metro_L, frame000077.png computation complete.
# Metro_L, frame000078.png computation complete.
# Metro_L, frame000079.png computation complete.
# Metro_L, frame000080.png computation complete.
# Metro_L, frame000081.png computation complete.
# Metro_L, frame000082.png computation complete.
# Metro_L, frame000083.png computation complete.
# Metro_L, frame000084.png computation complete.
# Metro_L, frame000085.png computation complete.
# Metro_L, frame000086.png computation complete.
# Metro_L, frame000087.png computation complete.
# Metro_L, frame000088.png computation complete.
# Metro_L, frame000089.png computation complete.
# Metro_L, frame000090.png computation complete.
# Metro_L, frame000091.png computation complete.
# Metro_L, frame000092.png computation complete.
# Metro_L, frame000093.png computation complete.
# Metro_L, frame000094.png computation complete.
# Metro_L, frame000095.png computation complete.
# Metro_L, frame000096.png computation complete.
# Metro_L, frame000097.png computation complete.
# Metro_L, frame000098.png computation complete.
# Metro_L, frame000099.png computation complete.
# Metro_L, frame000100.png computation complete.
# Metro_L, frame000101.png computation complete.
# Metro_L, frame000102.png computation complete.
# Metro_L, frame000103.png computation complete.
# Metro_L, frame000104.png computation complete.
# Metro_L, frame000105.png computation complete.
# Metro_L, frame000106.png computation complete.
# Metro_L, frame000107.png computation complete.
# Metro_L, frame000108.png computation complete.
# Metro_L, frame000109.png computation complete.
# Metro_L, frame000110.png computation complete.
# Metro_L, frame000111.png computation complete.
# Metro_L, frame000112.png computation complete.
# Metro_L, frame000113.png computation complete.
# Metro_L, frame000114.png computation complete.
# Metro_L, frame000115.png computation complete.
# Metro_L, frame000116.png computation complete.
# Metro_L, frame000117.png computation complete.
# Metro_L, frame000118.png computation complete.
# Metro_L, frame000119.png computation complete.
# Metro_L, frame000120.png computation complete.
# Metro_L, frame000121.png computation complete.
# Metro_L, frame000122.png computation complete.
# Metro_L, frame000123.png computation complete.
# Metro_L, frame000124.png computation complete.
# Metro_L, frame000125.png computation complete.
# Metro_L, frame000126.png computation complete.
# Metro_L, frame000127.png computation complete.
# Metro_L, frame000128.png computation complete.
# Metro_L, frame000129.png computation complete.
# Metro_L, frame000130.png computation complete.
# Metro_L, frame000131.png computation complete.
# Metro_L, frame000132.png computation complete.
# Metro_L, frame000133.png computation complete.
# Metro_L, frame000134.png computation complete.
# Metro_L, frame000135.png computation complete.
# Metro_L, frame000136.png computation complete.
# Metro_L, frame000137.png computation complete.
# Metro_L, frame000138.png computation complete.
# Metro_L, frame000139.png computation complete.
# Metro_L, frame000140.png computation complete.
# Metro_L, frame000141.png computation complete.
# Metro_L, frame000142.png computation complete.
# Metro_L, frame000143.png computation complete.
# Metro_L, frame000144.png computation complete.
# Metro_L, frame000145.png computation complete.
# Metro_L, frame000146.png computation complete.
# Metro_L, frame000147.png computation complete.
# Metro_L, frame000148.png computation complete.
# Metro_L, frame000149.png computation complete.
# Metro_L, frame000150.png computation complete.
# Metro_L, frame000151.png computation complete.
# Metro_L, frame000152.png computation complete.
# Metro_L, frame000153.png computation complete.
# Metro_L, frame000154.png computation complete.
# Metro_L, frame000155.png computation complete.
# Metro_L, frame000156.png computation complete.
# Metro_L, frame000157.png computation complete.
# Metro_L, frame000158.png computation complete.
# Metro_L, frame000159.png computation complete.
# Metro_L, frame000160.png computation complete.
# Metro_L, frame000161.png computation complete.
# Metro_L, frame000162.png computation complete.
# Metro_L, frame000163.png computation complete.
# Metro_L, frame000164.png computation complete.
# Metro_L, frame000165.png computation complete.
# Metro_L, frame000166.png computation complete.
# Metro_L, frame000167.png computation complete.
# Metro_L, frame000168.png computation complete.
# Metro_L, frame000169.png computation complete.
# Metro_L, frame000170.png computation complete.
# Metro_L, frame000171.png computation complete.
# Metro_L, frame000172.png computation complete.
# Metro_L, frame000173.png computation complete.
# Metro_L, frame000174.png computation complete.
# Metro_L, frame000175.png computation complete.
# Metro_L, frame000176.png computation complete.
# Metro_L, frame000177.png computation complete.
# Metro_L, frame000178.png computation complete.
# Metro_L, frame000179.png computation complete.
# Metro_L, frame000180.png computation complete.
# Metro_L, frame000181.png computation complete.
# Metro_L, frame000182.png computation complete.
# Metro_L, frame000183.png computation complete.
# Metro_L, frame000184.png computation complete.
# Metro_L, frame000185.png computation complete.
# Metro_L, frame000186.png computation complete.
# Metro_L, frame000187.png computation complete.
# Metro_L, frame000188.png computation complete.
# Metro_L, frame000189.png computation complete.
# Metro_L, frame000190.png computation complete.
# Metro_L, frame000191.png computation complete.
# Metro_L, frame000192.png computation complete.
# Metro_L, frame000193.png computation complete.
# Metro_L, frame000194.png computation complete.
# Metro_L, frame000195.png computation complete.
# Metro_L, frame000196.png computation complete.
# Metro_L, frame000197.png computation complete.
# Metro_L, frame000198.png computation complete.
# Metro_L, frame000199.png computation complete.
# Metro_L, frame000200.png computation complete.
# Metro_L, frame000201.png computation complete.
# Metro_L, frame000202.png computation complete.
# Metro_L, frame000203.png computation complete.
# Metro_L, frame000204.png computation complete.
# Metro_L, frame000205.png computation complete.
# Metro_L, frame000206.png computation complete.
# Metro_L, frame000207.png computation complete.
# Metro_L, frame000208.png computation complete.
# Metro_L, frame000209.png computation complete.
# Metro_L, frame000210.png computation complete.
# Metro_L, frame000211.png computation complete.
# Metro_L, frame000212.png computation complete.
# Metro_L, frame000213.png computation complete.
# Metro_L, frame000214.png computation complete.
# Metro_L, frame000215.png computation complete.
# Metro_L, frame000216.png computation complete.
# Metro_L, frame000217.png computation complete.
# Metro_L, frame000218.png computation complete.
# Metro_L, frame000219.png computation complete.
# Metro_L, frame000220.png computation complete.
# Metro_L, frame000221.png computation complete.
# Metro_L, frame000222.png computation complete.
# Metro_L, frame000223.png computation complete.
# Metro_L, frame000224.png computation complete.
# Metro_L, frame000225.png computation complete.
# Metro_L, frame000226.png computation complete.
# Metro_L, frame000227.png computation complete.
# Metro_L, frame000228.png computation complete.
# Metro_L, frame000229.png computation complete.
# Metro_L, frame000230.png computation complete.
# Metro_L, frame000231.png computation complete.
# Metro_L, frame000232.png computation complete.
# Metro_L, frame000233.png computation complete.
# Metro_L, frame000234.png computation complete.
# Metro_L, frame000235.png computation complete.
# Metro_L, frame000236.png computation complete.
# Metro_L, frame000237.png computation complete.
# Metro_L, frame000238.png computation complete.
# Metro_L, frame000239.png computation complete.
# Metro_L, frame000240.png computation complete.
# Metro_L, frame000241.png computation complete.
# Metro_L, frame000242.png computation complete.
# Metro_L, frame000243.png computation complete.
# Metro_L, frame000244.png computation complete.
# Metro_L, frame000245.png computation complete.
# Metro_L, frame000246.png computation complete.
# Metro_L, frame000247.png computation complete.
# Metro_L, frame000248.png computation complete.
# Metro_L, frame000249.png computation complete.
# Metro_L, frame000250.png computation complete.
# Metro_L, frame000251.png computation complete.
# Metro_L, frame000252.png computation complete.
# Metro_L, frame000253.png computation complete.
# Metro_L, frame000254.png computation complete.
# Metro_L, frame000255.png computation complete.
# Metro_L, frame000256.png computation complete.
# Metro_L, frame000257.png computation complete.
# Metro_L, frame000258.png computation complete.
# Metro_L, frame000259.png computation complete.
# Metro_L, frame000260.png computation complete.
# Metro_L, frame000261.png computation complete.
# Metro_L, frame000262.png computation complete.
# Metro_L, frame000263.png computation complete.
# Metro_L, frame000264.png computation complete.
# Metro_L, frame000265.png computation complete.
# Metro_L, frame000266.png computation complete.
# Metro_L, frame000267.png computation complete.
# Metro_L, frame000268.png computation complete.
# Metro_L, frame000269.png computation complete.
# Metro_L, frame000270.png computation complete.
# Metro_L, frame000271.png computation complete.
# Metro_L, frame000272.png computation complete.
# Metro_L, frame000273.png computation complete.
# Metro_L, frame000274.png computation complete.
# Metro_L, frame000275.png computation complete.
# Metro_L, frame000276.png computation complete.
# Metro_L, frame000277.png computation complete.
# Metro_L, frame000278.png computation complete.
# Metro_L, frame000279.png computation complete.
# Metro_L, frame000280.png computation complete.
# Metro_L, frame000281.png computation complete.
# Metro_L, frame000282.png computation complete.
# Metro_L, frame000283.png computation complete.
# Metro_L, frame000284.png computation complete.
# Metro_L, frame000285.png computation complete.
# Metro_L, frame000286.png computation complete.
# Metro_L, frame000287.png computation complete.
# Metro_L, frame000288.png computation complete.
# Metro_L, frame000289.png computation complete.
# Metro_L, frame000290.png computation complete.
# Metro_L, frame000291.png computation complete.
# Metro_L, frame000292.png computation complete.
# Metro_L, frame000293.png computation complete.
# Metro_L, frame000294.png computation complete.
# Metro_L, frame000295.png computation complete.
# Metro_L, frame000296.png computation complete.
# Metro_L, frame000297.png computation complete.
# Metro_L, frame000298.png computation complete.
# Metro_L, frame000299.png computation complete.
# Metro_L, frame000300.png computation complete.
# Metro_L, frame000301.png computation complete.
# Metro_L, frame000302.png computation complete.
# Metro_L, frame000303.png computation complete.
# Metro_L, frame000304.png computation complete.
# Metro_L, frame000305.png computation complete.
# Metro_L, frame000306.png computation complete.
# Metro_L, frame000307.png computation complete.
# Metro_L, frame000308.png computation complete.
# Metro_L, frame000309.png computation complete.
# Metro_L, frame000310.png computation complete.
# Metro_L, frame000311.png computation complete.
# Metro_L, frame000312.png computation complete.
# Metro_L, frame000313.png computation complete.
# Metro_L, frame000314.png computation complete.
# Metro_L, frame000315.png computation complete.
# Metro_L, frame000316.png computation complete.
# Metro_L, frame000317.png computation complete.
# Metro_L, frame000318.png computation complete.
# Metro_L, frame000319.png computation complete.
# Metro_L, frame000320.png computation complete.
# Metro_L, frame000321.png computation complete.
# Metro_L, frame000322.png computation complete.
# Metro_L, frame000323.png computation complete.
# Metro_L, frame000324.png computation complete.
# Metro_L, frame000325.png computation complete.
# Metro_L, frame000326.png computation complete.
# Metro_L, frame000327.png computation complete.
# Metro_L, frame000328.png computation complete.
# Metro_L, frame000329.png computation complete.
# Metro_L, frame000330.png computation complete.
# Metro_L, frame000331.png computation complete.
# Metro_L, frame000332.png computation complete.
# Metro_L, frame000333.png computation complete.
# Metro_L, frame000334.png computation complete.
# Metro_L, frame000335.png computation complete.
# Metro_L, frame000336.png computation complete.
# Metro_L, frame000337.png computation complete.
# Metro_L, frame000338.png computation complete.
# Metro_L, frame000339.png computation complete.
# Metro_L, frame000340.png computation complete.
# Metro_L, frame000341.png computation complete.
# Metro_L, frame000342.png computation complete.
# Metro_L, frame000343.png computation complete.
# Metro_L, frame000344.png computation complete.
# Metro_L, frame000345.png computation complete.
# Metro_L, frame000346.png computation complete.
# Metro_L, frame000347.png computation complete.
# Metro_L, frame000348.png computation complete.
# Metro_L, frame000349.png computation complete.
# Metro_L, frame000350.png computation complete.
# Metro_L, frame000351.png computation complete.
# Metro_L, frame000352.png computation complete.
# Metro_L, frame000353.png computation complete.
# Metro_L, frame000354.png computation complete.
# Metro_L, frame000355.png computation complete.
# Metro_L, frame000356.png computation complete.
# Metro_L, frame000357.png computation complete.
# Metro_L, frame000358.png computation complete.
# Metro_L, frame000359.png computation complete.
# Metro_L, frame000360.png computation complete.
# Metro_L, frame000361.png computation complete.
# Metro_L, frame000362.png computation complete.
# Metro_L, frame000363.png computation complete.
# Metro_L, frame000364.png computation complete.
# Metro_L, frame000365.png computation complete.
# Metro_L, frame000366.png computation complete.
# Metro_L, frame000367.png computation complete.
# Metro_L, frame000368.png computation complete.
# Metro_L, frame000369.png computation complete.
# Metro_L, frame000370.png computation complete.
# Metro_L, frame000371.png computation complete.
# Metro_L, frame000372.png computation complete.
# Metro_L, frame000373.png computation complete.
# Metro_L, frame000374.png computation complete.
# Metro_L, frame000375.png computation complete.
# Metro_L, frame000376.png computation complete.
# Metro_L, frame000377.png computation complete.
# Metro_L, frame000378.png computation complete.
# Metro_L, frame000379.png computation complete.
# Metro_L, frame000380.png computation complete.
# Metro_L, frame000381.png computation complete.
# Metro_L, frame000382.png computation complete.
# Metro_L, frame000383.png computation complete.
# Metro_L, frame000384.png computation complete.
# Metro_L, frame000385.png computation complete.
# Metro_L, frame000386.png computation complete.
# Metro_L, frame000387.png computation complete.
# Metro_L, frame000388.png computation complete.
# Metro_L, frame000389.png computation complete.
# Metro_L, frame000390.png computation complete.
# Metro_L, frame000391.png computation complete.
# Metro_L, frame000392.png computation complete.
# Metro_L, frame000393.png computation complete.
# Metro_L, frame000394.png computation complete.
# Metro_L, frame000395.png computation complete.
# Metro_L, frame000396.png computation complete.
# Metro_L, frame000397.png computation complete.
# Metro_L, frame000398.png computation complete.
# Metro_L, frame000399.png computation complete.
# Metro_L, frame000400.png computation complete.
# Metro_L, frame000401.png computation complete.
# Metro_L, frame000402.png computation complete.
# Metro_L, frame000403.png computation complete.
# Metro_L, frame000404.png computation complete.
# Metro_L, frame000405.png computation complete.
# Metro_L, frame000406.png computation complete.
# Metro_L, frame000407.png computation complete.
# Metro_L, frame000408.png computation complete.
# Metro_L, frame000409.png computation complete.
# Metro_L, frame000410.png computation complete.
# Metro_L, frame000411.png computation complete.
# Metro_L, frame000412.png computation complete.
# Metro_L, frame000413.png computation complete.
# Metro_L, frame000414.png computation complete.
# Metro_L, frame000415.png computation complete.
# Metro_L, frame000416.png computation complete.
# Metro_L, frame000417.png computation complete.
# Metro_L, frame000418.png computation complete.
# Metro_L, frame000419.png computation complete.
# Metro_L, frame000420.png computation complete.
# Metro_L, frame000421.png computation complete.
# Metro_L, frame000422.png computation complete.
# Metro_L, frame000423.png computation complete.
# Metro_L, frame000424.png computation complete.
# Metro_L, frame000425.png computation complete.
# Metro_L, frame000426.png computation complete.
# Metro_L, frame000427.png computation complete.
# Metro_L, frame000428.png computation complete.
# Metro_L, frame000429.png computation complete.
# Metro_L, frame000430.png computation complete.
# Metro_L, frame000431.png computation complete.
# Metro_L, frame000432.png computation complete.
# Metro_L, frame000433.png computation complete.
# Metro_L, frame000434.png computation complete.
# Metro_L, frame000435.png computation complete.
# Metro_L, frame000436.png computation complete.
# Metro_L, frame000437.png computation complete.
# Metro_L, frame000438.png computation complete.
# Metro_L, frame000439.png computation complete.
# Metro_L, frame000440.png computation complete.
# Metro_L, frame000441.png computation complete.
# Metro_L, frame000442.png computation complete.
# Metro_L, frame000443.png computation complete.
# Metro_L, frame000444.png computation complete.
# Metro_L, frame000445.png computation complete.
# Metro_L, frame000446.png computation complete.
# Metro_L, frame000447.png computation complete.
# Metro_L, frame000448.png computation complete.
# Metro_L, frame000449.png computation complete.
# Metro_L, frame000450.png computation complete.
# Metro_L, frame000451.png computation complete.
# Metro_L, frame000452.png computation complete.
# Metro_L, frame000453.png computation complete.
# Metro_L, frame000454.png computation complete.
# Metro_L, frame000455.png computation complete.
# Metro_L, frame000456.png computation complete.
# Metro_L, frame000457.png computation complete.
# Metro_L, frame000458.png computation complete.
# Metro_L, frame000459.png computation complete.
# Metro_L, frame000460.png computation complete.
# Metro_L, frame000461.png computation complete.
# Metro_L, frame000462.png computation complete.
# Metro_L, frame000463.png computation complete.
# Metro_L, frame000464.png computation complete.
# Metro_L, frame000465.png computation complete.
# Metro_L, frame000466.png computation complete.
# Metro_L, frame000467.png computation complete.
# Metro_L, frame000468.png computation complete.
# Metro_L, frame000469.png computation complete.
# Metro_L, frame000470.png computation complete.
# Metro_L, frame000471.png computation complete.
# Metro_L, frame000472.png computation complete.
# Metro_L, frame000473.png computation complete.
# Metro_L, frame000474.png computation complete.
# Metro_L, frame000475.png computation complete.
# Metro_L, frame000476.png computation complete.
# Metro_L, frame000477.png computation complete.
# Metro_L, frame000478.png computation complete.
# Metro_L, frame000479.png computation complete.
# Metro_L, frame000480.png computation complete.
# Metro_L, frame000481.png computation complete.
# Metro_L, frame000482.png computation complete.
# Metro_L, frame000483.png computation complete.
# Metro_L, frame000484.png computation complete.
# Metro_L, frame000485.png computation complete.
# Metro_L, frame000486.png computation complete.
# Metro_L, frame000487.png computation complete.
# Metro_L, frame000488.png computation complete.
# Metro_L, frame000489.png computation complete.
# Metro_L, frame000490.png computation complete.
# Metro_L, frame000491.png computation complete.
# Metro_L, frame000492.png computation complete.
# Metro_L, frame000493.png computation complete.
# Metro_L, frame000494.png computation complete.
# Metro_L, frame000495.png computation complete.
# Metro_L, frame000496.png computation complete.
# Metro_L, frame000497.png computation complete.
# Metro_L, frame000498.png computation complete.
# Metro_L, frame000499.png computation complete.
# Metro_L, frame000500.png computation complete.
# Metro_L, frame000501.png computation complete.
# Metro_L, frame000502.png computation complete.
# Metro_L, frame000503.png computation complete.
# Metro_L, frame000504.png computation complete.
# Metro_L, frame000505.png computation complete.
# Metro_L, frame000506.png computation complete.
# Metro_L, frame000507.png computation complete.
# Metro_L, frame000508.png computation complete.
# Metro_L, frame000509.png computation complete.
# Metro_L, frame000510.png computation complete.
# Metro_L, frame000511.png computation complete.
# Metro_L, frame000512.png computation complete.
# Metro_L, frame000513.png computation complete.
# Metro_L, frame000514.png computation complete.
# Metro_L, frame000515.png computation complete.
# Metro_L, frame000516.png computation complete.
# Metro_L, frame000517.png computation complete.
# Metro_L, frame000518.png computation complete.
# Metro_L, frame000519.png computation complete.
# Metro_L, frame000520.png computation complete.
# Metro_L, frame000521.png computation complete.
# ...
# Metro_L, frame004162.png computation complete.
# Metro_L, frame004163.png computation complete.
# Metro_L, frame004164.png computation complete.
# Metro_L, frame004165.png computation complete.
# Metro_L, frame004166.png computation complete.
# Metro_L, frame004167.png computation complete.
# Metro_L, frame004168.png computation complete.
# Metro_L, frame004169.png computation complete.
# Metro_L, frame004170.png computation complete.
# Metro_L, frame004171.png computation complete.
# Metro_L, frame004172.png computation complete.
# Metro_L, frame004173.png computation complete.
# Metro_L, frame004174.png computation complete.
# Metro_L, frame004175.png computation complete.
# Metro_L, frame004176.png computation complete.
# Metro_L, frame004177.png computation complete.
# Metro_L, frame004178.png computation complete.
# Metro_L, frame004179.png computation complete.
# Metro_L, frame004180.png computation complete.
# Metro_L, frame004181.png computation complete.
# Metro_L, frame004182.png computation complete.
# Metro_L, frame004183.png computation complete.
# Metro_L, frame004184.png computation complete.
# Metro_L, frame004185.png computation complete.
# Metro_L, frame004186.png computation complete.
# Metro_L, frame004187.png computation complete.
# Metro_L, frame004188.png computation complete.
# Metro_L, frame004189.png computation complete.
# Metro_L, frame004190.png computation complete.
# Metro_L, frame004191.png computation complete.
# Metro_L, frame004192.png computation complete.
# Metro_L, frame004193.png computation complete.
# Metro_L, frame004194.png computation complete.
# Metro_L, frame004195.png computation complete.
# Metro_L, frame004196.png computation complete.
# Metro_L, frame004197.png computation complete.
# Metro_L, frame004198.png computation complete.
# Metro_L, frame004199.png computation complete.
# Metro_L, frame004200.png computation complete.
# Metro_L, frame004201.png computation complete.
# Metro_L, frame004202.png computation complete.
# Metro_L, frame004203.png computation complete.
# Metro_L, frame004204.png computation complete.
# Metro_L, frame004205.png computation complete.
# Metro_L, frame004206.png computation complete.
# Metro_L, frame004207.png computation complete.
# Metro_L, frame004208.png computation complete.
# Metro_L, frame004209.png computation complete.
# Metro_L, frame004210.png computation complete.
# Metro_L, frame004211.png computation complete.
# Metro_L, frame004212.png computation complete.
# Metro_L, frame004213.png computation complete.
# Metro_L, frame004214.png computation complete.
# Metro_L, frame004215.png computation complete.
# Metro_L, frame004216.png computation complete.
# Metro_L, frame004217.png computation complete.
# Metro_L, frame004218.png computation complete.
# Metro_L, frame004219.png computation complete.
# Metro_L, frame004220.png computation complete.
# Metro_L, frame004221.png computation complete.
# Metro_L, frame004222.png computation complete.
# Metro_L, frame004223.png computation complete.
# Metro_L, frame004224.png computation complete.
# Metro_L, frame004225.png computation complete.
# Metro_L, frame004226.png computation complete.
# Metro_L, frame004227.png computation complete.
# Metro_L, frame004228.png computation complete.
# Metro_L, frame004229.png computation complete.
# Metro_L, frame004230.png computation complete.
# Metro_L, frame004231.png computation complete.
# Metro_L, frame004232.png computation complete.
# Metro_L, frame004233.png computation complete.
# Metro_L, frame004234.png computation complete.
# Metro_L, frame004235.png computation complete.
# Metro_L, frame004236.png computation complete.
# Metro_L, frame004237.png computation complete.
# Metro_L, frame004238.png computation complete.
# Metro_L, frame004239.png computation complete.
# Metro_L, frame004240.png computation complete.
# Metro_L, frame004241.png computation complete.
# Metro_L, frame004242.png computation complete.
# Metro_L, frame004243.png computation complete.
# Metro_L, frame004244.png computation complete.
# Metro_L, frame004245.png computation complete.
# Metro_L, frame004246.png computation complete.
# Metro_L, frame004247.png computation complete.
# Metro_L, frame004248.png computation complete.
# Metro_L, frame004249.png computation complete.
# Metro_L, frame004250.png computation complete.
# Metro_L, frame004251.png computation complete.
# Metro_L, frame004252.png computation complete.
# Metro_L, frame004253.png computation complete.
# Metro_L, frame004254.png computation complete.
# Metro_L, frame004255.png computation complete.
# Metro_L, frame004256.png computation complete.
# Metro_L, frame004257.png computation complete.
# Metro_L, frame004258.png computation complete.
# Metro_L, frame004259.png computation complete.
# Metro_L, frame004260.png computation complete.
# Metro_L, frame004261.png computation complete.
# Metro_L, frame004262.png computation complete.
# Metro_L, frame004263.png computation complete.
# Metro_L, frame004264.png computation complete.
# Metro_L, frame004265.png computation complete.
# Metro_L, frame004266.png computation complete.
# Metro_L, frame004267.png computation complete.
# Metro_L, frame004268.png computation complete.
# Metro_L, frame004269.png computation complete.
# Metro_L, frame004270.png computation complete.
# Metro_L, frame004271.png computation complete.
# Metro_L, frame004272.png computation complete.
# Metro_L, frame004273.png computation complete.
# Metro_L, frame004274.png computation complete.
# Metro_L, frame004275.png computation complete.
# Metro_L, frame004276.png computation complete.
# Metro_L, frame004277.png computation complete.
# Metro_L, frame004278.png computation complete.
# Metro_L, frame004279.png computation complete.
# Metro_L, frame004280.png computation complete.
# Metro_L, frame004281.png computation complete.
# Metro_L, frame004282.png computation complete.
# Metro_L, frame004283.png computation complete.
# Metro_L, frame004284.png computation complete.
# Metro_L, frame004285.png computation complete.
# Metro_L, frame004286.png computation complete.
# Metro_L, frame004287.png computation complete.
# Metro_L, frame004288.png computation complete.
# Metro_L, frame004289.png computation complete.
# Metro_L, frame004290.png computation complete.
# Metro_L, frame004291.png computation complete.
# Metro_L, frame004292.png computation complete.
# Metro_L, frame004293.png computation complete.
# Metro_L, frame004294.png computation complete.
# Metro_L, frame004295.png computation complete.
# Metro_L, frame004296.png computation complete.
# Metro_L, frame004297.png computation complete.
# Metro_L, frame004298.png computation complete.
# Metro_L, frame004299.png computation complete.
# Metro_L, frame004300.png computation complete.
# Metro_L, frame004301.png computation complete.
# Metro_L, frame004302.png computation complete.
# Metro_L, frame004303.png computation complete.
# Metro_L, frame004304.png computation complete.
# Metro_L, frame004305.png computation complete.
# Metro_L, frame004306.png computation complete.
# Metro_L, frame004307.png computation complete.
# Metro_L, frame004308.png computation complete.
# Metro_L, frame004309.png computation complete.
# Metro_L, frame004310.png computation complete.
# Metro_L, frame004311.png computation complete.
# Metro_L, frame004312.png computation complete.
# Metro_L, frame004313.png computation complete.
# Metro_L, frame004314.png computation complete.
# Metro_L, frame004315.png computation complete.
# Metro_L, frame004316.png computation complete.
# Metro_L, frame004317.png computation complete.
# Metro_L, frame004318.png computation complete.
# Metro_L, frame004319.png computation complete.
# Metro_L, frame004320.png computation complete.
# Metro_L, frame004321.png computation complete.
# Metro_L, frame004322.png computation complete.
# Metro_L, frame004323.png computation complete.
# Metro_L, frame004324.png computation complete.
# Metro_L, frame004325.png computation complete.
# Metro_L, frame004326.png computation complete.
# Metro_L, frame004327.png computation complete.
# Metro_L, frame004328.png computation complete.
# Metro_L, frame004329.png computation complete.
# Metro_L, frame004330.png computation complete.
# Metro_L, frame004331.png computation complete.
# Metro_L, frame004332.png computation complete.
# Metro_L, frame004333.png computation complete.
# Metro_L, frame004334.png computation complete.
# Metro_L, frame004335.png computation complete.
# Metro_L, frame004336.png computation complete.
# Metro_L, frame004337.png computation complete.
# Metro_L, frame004338.png computation complete.
# Metro_L, frame004339.png computation complete.
# Metro_L, frame004340.png computation complete.
# Metro_L, frame004341.png computation complete.
# Metro_L, frame004342.png computation complete.
# Metro_L, frame004343.png computation complete.
# Metro_L, frame004344.png computation complete.
# Metro_L, frame004345.png computation complete.
# Metro_L, frame004346.png computation complete.
# Metro_L, frame004347.png computation complete.
# Metro_L, frame004348.png computation complete.
# Metro_L, frame004349.png computation complete.
# Metro_L, frame004350.png computation complete.
# Metro_L, frame004351.png computation complete.
# Metro_L, frame004352.png computation complete.
# Metro_L, frame004353.png computation complete.
# Metro_L, frame004354.png computation complete.
# Metro_L, frame004355.png computation complete.
# Metro_L, frame004356.png computation complete.
# Metro_L, frame004357.png computation complete.
# Metro_L, frame004358.png computation complete.
# Metro_L, frame004359.png computation complete.
# Metro_L, frame004360.png computation complete.
# Metro_L, frame004361.png computation complete.
# Metro_L, frame004362.png computation complete.
# Metro_L, frame004363.png computation complete.
# Metro_L, frame004364.png computation complete.
# Metro_L, frame004365.png computation complete.
# Metro_L, frame004366.png computation complete.
# Metro_L, frame004367.png computation complete.
# Metro_L, frame004368.png computation complete.
# Metro_L, frame004369.png computation complete.
# Metro_L, frame004370.png computation complete.
# Metro_L, frame004371.png computation complete.
# Metro_L, frame004372.png computation complete.
# Metro_L, frame004373.png computation complete.
# Metro_L, frame004374.png computation complete.
# Metro_L, frame004375.png computation complete.
# Metro_L, frame004376.png computation complete.
# Metro_L, frame004377.png computation complete.
# Metro_L, frame004378.png computation complete.
# Metro_L, frame004379.png computation complete.
# Metro_L, frame004380.png computation complete.
# Metro_L, frame004381.png computation complete.
# Metro_L, frame004382.png computation complete.
# Metro_L, frame004383.png computation complete.
# Metro_L, frame004384.png computation complete.
# Metro_L, frame004385.png computation complete.
# Metro_L, frame004386.png computation complete.
# Metro_L, frame004387.png computation complete.
# Metro_L, frame004388.png computation complete.
# Metro_L, frame004389.png computation complete.
# Metro_L, frame004390.png computation complete.
# Metro_L, frame004391.png computation complete.
# Metro_L, frame004392.png computation complete.
# Metro_L, frame004393.png computation complete.
# Metro_L, frame004394.png computation complete.
# Metro_L, frame004395.png computation complete.
# Metro_L, frame004396.png computation complete.
# Metro_L, frame004397.png computation complete.
# Metro_L, frame004398.png computation complete.
# Metro_L, frame004399.png computation complete.
# Metro_L, frame004400.png computation complete.
# Metro_L, frame004401.png computation complete.
# Metro_L, frame004402.png computation complete.
# Metro_L, frame004403.png computation complete.
# Metro_L, frame004404.png computation complete.
# Metro_L, frame004405.png computation complete.
# Metro_L, frame004406.png computation complete.
# Metro_L, frame004407.png computation complete.
# Metro_L, frame004408.png computation complete.
# Metro_L, frame004409.png computation complete.
# Metro_L, frame004410.png computation complete.
# Metro_L, frame004411.png computation complete.
# Metro_L, frame004412.png computation complete.
# Metro_L, frame004413.png computation complete.
# Metro_L, frame004414.png computation complete.
# Metro_L, frame004415.png computation complete.
# Metro_L, frame004416.png computation complete.
# Metro_L, frame004417.png computation complete.
# Metro_L, frame004418.png computation complete.
# Metro_L, frame004419.png computation complete.
# Metro_L, frame004420.png computation complete.
# Metro_L, frame004421.png computation complete.
# Metro_L, frame004422.png computation complete.
# Metro_L, frame004423.png computation complete.
# Metro_L, frame004424.png computation complete.
# Metro_L, frame004425.png computation complete.
# Metro_L, frame004426.png computation complete.
# Metro_L, frame004427.png computation complete.
# Metro_L, frame004428.png computation complete.
# Metro_L, frame004429.png computation complete.
# Metro_L, frame004430.png computation complete.
# Metro_L, frame004431.png computation complete.
# Metro_L, frame004432.png computation complete.
# Metro_L, frame004433.png computation complete.
# Metro_L, frame004434.png computation complete.
# Metro_L, frame004435.png computation complete.
# Metro_L, frame004436.png computation complete.
# Metro_L, frame004437.png computation complete.
# Metro_L, frame004438.png computation complete.
# Metro_L, frame004439.png computation complete.
# Metro_L, frame004440.png computation complete.
# Metro_L, frame004441.png computation complete.
# Metro_L, frame004442.png computation complete.
# Metro_L, frame004443.png computation complete.
# Metro_L, frame004444.png computation complete.
# Metro_L, frame004445.png computation complete.
# Metro_L, frame004446.png computation complete.
# Metro_L, frame004447.png computation complete.
# Metro_L, frame004448.png computation complete.
# Metro_L, frame004449.png computation complete.
# Metro_L, frame004450.png computation complete.
# Metro_L, frame004451.png computation complete.
# Metro_L, frame004452.png computation complete.
# Metro_L, frame004453.png computation complete.
# Metro_L, frame004454.png computation complete.
# Metro_L, frame004455.png computation complete.
# Metro_L, frame004456.png computation complete.
# Metro_L, frame004457.png computation complete.
# Metro_L, frame004458.png computation complete.
# Metro_L, frame004459.png computation complete.
# Metro_L, frame004460.png computation complete.
# Metro_L, frame004461.png computation complete.
# Metro_L, frame004462.png computation complete.
# Metro_L, frame004463.png computation complete.
# Metro_L, frame004464.png computation complete.
# Metro_L, frame004465.png computation complete.
# Metro_L, frame004466.png computation complete.
# Metro_L, frame004467.png computation complete.
# Metro_L, frame004468.png computation complete.
# Metro_L, frame004469.png computation complete.
# Metro_L, frame004470.png computation complete.
# Metro_L, frame004471.png computation complete.
# Metro_L, frame004472.png computation complete.
# Metro_L, frame004473.png computation complete.
# Metro_L, frame004474.png computation complete.
# Metro_L, frame004475.png computation complete.
# Metro_L, frame004476.png computation complete.
# Metro_L, frame004477.png computation complete.
# Metro_L, frame004478.png computation complete.
# Metro_L, frame004479.png computation complete.
# Metro_L, frame004480.png computation complete.
# Metro_L, frame004481.png computation complete.
# Metro_L, frame004482.png computation complete.
# Metro_L, frame004483.png computation complete.
# Metro_L, frame004484.png computation complete.
# Metro_L, frame004485.png computation complete.
# Metro_L, frame004486.png computation complete.
# Metro_L, frame004487.png computation complete.
# Metro_L, frame004488.png computation complete.
# Metro_L, frame004489.png computation complete.
# Metro_L, frame004490.png computation complete.
# Metro_L, frame004491.png computation complete.
# Metro_L, frame004492.png computation complete.
# Metro_L, frame004493.png computation complete.
# Metro_L, frame004494.png computation complete.
# Metro_L, frame004495.png computation complete.
# Metro_L, frame004496.png computation complete.
# Metro_L, frame004497.png computation complete.
# Metro_L, frame004498.png computation complete.
# Metro_L, frame004499.png computation complete.
# Metro_L, frame004500.png computation complete.
# Metro_L, frame004501.png computation complete.
